# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('preprocessed_data.csv')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
new_df = df[['Restaurant ID','Restaurant Name','Cuisines','Price range','Aggregate rating','Votes']]
new_df
# Out:
#       Restaurant ID           Restaurant Name  \
# 0           6317637          Le Petit Souffle
# 1           6304287          Izakaya Kikufuji
# 2           6300002    Heat - Edsa Shangri-La
# 3           6318506                      Ooma
# 4           6314302               Sambo Kojin
# ...             ...                       ...
# 9546        5915730               Naml۱ Gurme
# 9547        5908749              Ceviz A��ac۱
# 9548        5915807                     Huqqa
# 9549        5916112               A���k Kahve
# 9550        5927402  Walter's Coffee Roastery
#
#                               Cuisines  Price range  Aggregate rating  Votes
# 0           French, Japanese, Desserts            3               4.8    314
# 1                             Japanese            3               4.5    591
# 2     Seafood, Asian, Filipino, Indian            4               4.4    270
# 3                      Japanese, Sushi            4               4.9    365
# ...

# %%
new_df.isna().sum()
# Out:
# Restaurant ID       0
# Restaurant Name     0
# Cuisines            9
# Price range         0
# Aggregate rating    0
# Votes               0
# dtype: int64

# %%
new_df = new_df.dropna()
new_df.isna().sum()
# Out:
# Restaurant ID       0
# Restaurant Name     0
# Cuisines            0
# Price range         0
# Aggregate rating    0
# Votes               0
# dtype: int64

# %%
new_df.duplicated().sum()
# Out:
# 0

# %%
new_df['Restaurant Name'].duplicated().sum()
# Out:
# 2105

# %%
new_df= new_df.sort_values(by=['Restaurant Name','Aggregate rating'],ascending=False)
new_df.head()
# Out:
#       Restaurant ID       Restaurant Name  \
# 9523        6000871     �ukura��a Sofras۱
# 3120       18222559  {Niche} - Cafe & Bar
# 9334        7100938              wagamama
# 9454        6401789                tashas
# 4659       18361747    t Lounge by Dilmah
#
#                                          Cuisines  Price range  \
# 9523                                Kebab, Izgara            3
# 3120  North Indian, Chinese, Italian, Continental            3
# 9334                              Japanese, Asian            4
# 9454                          Cafe, Mediterranean            4
# 4659                          Cafe, Tea, Desserts            2
#
#       Aggregate rating  Votes
# 9523               4.4    296
# 3120               4.1    492
# 9334               3.7    131
# 9454               4.1    374
# 4659               3.6     34

# %%
new_df = new_df[new_df['Aggregate rating']>3.8]
new_df
# Out:
#       Restaurant ID          Restaurant Name  \
# 9523        6000871        �ukura��a Sofras۱
# 3120       18222559     {Niche} - Cafe & Bar
# 9454        6401789                   tashas
# 9385        6113857           sketch Gallery
# 1837       18418247               feel ALIVE
# ...             ...                      ...
# 2484       18233317           145 Kala Ghoda
# 2292        2100784  11th Avenue Cafe Bistro
# 751         2600031        10 Downing Street
# 2333        1400121        10 Downing Street
# 351        17057397                   'Ohana
#
#                                          Cuisines  Price range  \
# 9523                                Kebab, Izgara            3
# 3120  North Indian, Chinese, Italian, Continental            3
# 9454                          Cafe, Mediterranean            4
# 9385                        British, Contemporary            4
# 1837       North Indian, American, Asian, Biryani            3
# ...

# %%
new_df['Cuisines'] = new_df['Cuisines'].str.split(', ')
new_df
# Out:
#       Restaurant ID          Restaurant Name  \
# 9523        6000871        �ukura��a Sofras۱
# 3120       18222559     {Niche} - Cafe & Bar
# 9454        6401789                   tashas
# 9385        6113857           sketch Gallery
# 1837       18418247               feel ALIVE
# ...             ...                      ...
# 2484       18233317           145 Kala Ghoda
# 2292        2100784  11th Avenue Cafe Bistro
# 751         2600031        10 Downing Street
# 2333        1400121        10 Downing Street
# 351        17057397                   'Ohana
#
#                                            Cuisines  Price range  \
# 9523                                [Kebab, Izgara]            3
# 3120  [North Indian, Chinese, Italian, Continental]            3
# 9454                          [Cafe, Mediterranean]            4
# 9385                        [British, Contemporary]            4
# 1837       [North Indian, American, Asian, Biryani]            3
# ...

# %%
new_df = new_df.explode('Cuisines')
new_df
# Out:
#       Restaurant ID       Restaurant Name      Cuisines  Price range  \
# 9523        6000871     �ukura��a Sofras۱         Kebab            3
# 9523        6000871     �ukura��a Sofras۱        Izgara            3
# 3120       18222559  {Niche} - Cafe & Bar  North Indian            3
# 3120       18222559  {Niche} - Cafe & Bar       Chinese            3
# 3120       18222559  {Niche} - Cafe & Bar       Italian            3
# ...             ...                   ...           ...          ...
# 751         2600031     10 Downing Street  North Indian            3
# 751         2600031     10 Downing Street       Chinese            3
# 2333        1400121     10 Downing Street  North Indian            4
# 2333        1400121     10 Downing Street       Chinese            4
# 351        17057397                'Ohana      Hawaiian            3
#
#       Aggregate rating  Votes
# 9523               4.4    296
# 9523               4.4    296
# 3120               4.1    492
# ...

# %%
new_df['Cuisines'].value_counts()
# Out:
# Cuisines
# North Indian    323
# Italian         264
# Continental     223
# Chinese         222
# Cafe            201
#                ...
# Belgian           1
# Awadhi            1
# Irish             1
# Persian           1
# Durban            1
# Name: count, Length: 128, dtype: int64

# %%
cuisines = pd.crosstab(new_df['Restaurant Name'], new_df['Cuisines'])
cuisines
# Out:
# Cuisines                 Afghani  African  American  Andhra  Arabian  \
# Restaurant Name
# 'Ohana                         0        0         0       0        0
# 10 Downing Street              0        0         0       0        0
# 11th Avenue Cafe Bistro        0        0         1       0        0
# 145 Kala Ghoda                 0        0         0       0        0
# 19 Flavours Biryani            0        0         0       0        0
# ...                          ...      ...       ...     ...      ...
# feel ALIVE                     0        0         1       0        0
# sketch Gallery                 0        0         0       0        0
# tashas                         0        0         0       0        0
# {Niche} - Cafe & Bar           0        0         0       0        0
# �ukura��a Sofras۱              0        0         0       0        0
#
# Cuisines                 Argentine  Asian  Asian Fusion  Australian  Awadhi  \
# Restaurant Name
# ...

# %%
new_df['Restaurant Name'].sample(20, random_state=194)
# Out:
# 13                                             Guevarra's
# 6529    The Great Kabab Factory - Radisson Blu Plaza D...
# 313               The Nacoochee Village Tavern & Pizzeria
# 9515                                         Cafe Beverly
# 2343                                                  WTF
# 1149                                      Martin's Corner
# 2635                                               Diggin
# 7360                                     The Society Cafe
# 2113                                                 Nosh
# 7033                                      Big Yellow Door
# 7849                                      Cafeteria & Co.
# 9375                           Tuk Tuk Indian Street Food
# 2374                                               Aromas
# 300                                Shenanigan's Irish Pub
# 132                                       Mellow Mushroom
# 658                                         Cafe Alfresco
# ...

# %%
from scipy.spatial.distance import pdist, squareform
jaccardDist = pdist(cuisines.values, metric='jaccard')
jaccardMatrix = squareform(jaccardDist)
jaccardSim = 1 - jaccardMatrix
dfJaccard = pd.DataFrame(
    jaccardSim,
    index=cuisines.index,
    columns=cuisines.index)

dfJaccard
# Out:
# Restaurant Name          'Ohana  10 Downing Street  11th Avenue Cafe Bistro  \
# Restaurant Name
# 'Ohana                      1.0                0.0                 0.000000
# 10 Downing Street           0.0                1.0                 0.000000
# 11th Avenue Cafe Bistro     0.0                0.0                 1.000000
# 145 Kala Ghoda              0.0                0.0                 0.000000
# 19 Flavours Biryani         0.0                0.0                 0.000000
# ...                         ...                ...                      ...
# feel ALIVE                  0.0                0.0                 0.142857
# sketch Gallery              0.0                0.0                 0.000000
# tashas                      0.0                0.0                 0.200000
# {Niche} - Cafe & Bar        0.0                0.0                 0.333333
# �ukura��a Sofras۱           0.0                0.0                 0.000000
#
# ...

# %%
new_df['Restaurant Name'].sample(20)
# Out:
# 960                   Caf�� Bogchi
# 2337                         Mocha
# 4319                 Cafe Southall
# 5900                       Sinciti
# 2328         Square - Sayaji Hotel
# 620                     Applebee's
# 1213                        Bunker
# 2395                    Cocoa Tree
# 4638                     Big Chill
# 8209    New Town Cafe - Park Plaza
# 9232                Coffee Culture
# 9161             Effingut Brewerkz
# 538                Blue House Cafe
# 9464                        Marble
# 637                Sheroes Hangout
# 574                    Hot Palayok
# 581                          Tamba
# 647                         @Mango
# 9478                Harissa Bistro
# 2400                   Spice Kraft
# Name: Restaurant Name, dtype: object

# %%
rec = 'Ooma'

sim = dfJaccard.loc[rec].sort_values(ascending=False)
sim = pd.DataFrame({'Restaurant Name': sim.index, 'simScore': sim.values})
sim = sim[(sim['Restaurant Name']!= resto) & (sim['simScore']>=0.7)].head(5)
Records = pd.merge(sim,new_df[['Restaurant Name','Aggregate rating']],how='inner',on='Restaurant Name')
FinalRecords = Records.sort_values('Aggregate rating',ascending=False).drop_duplicates('Restaurant Name',keep='first')
